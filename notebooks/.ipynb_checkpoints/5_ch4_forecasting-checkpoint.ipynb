# %% [markdown]
# # libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from pathlib import Path
import pickle
import json

import sys
sys.path.append('../')
from src import forecasting as fc
print('forecasting imported successfully!')
# Out:
# forecasting imported successfully!

# %% [markdown]
# # load data
#
# - "processed" folder containing train and test sets:
#   - "C:\Users\aplor\Documents\GitHub\greenhouse-gas-forecasting\data\processed"
#
# - "forecasting_data" folder containing model specs, fitted models, and calibration files:
#   - "C:\Users\aplor\Documents\GitHub\greenhouse-gas-forecasting\data\forecasting_data"

# %% [markdown]
# ## train and test sets

# %%
# load the pickle files

output_dir = Path("../data/processed")

train_preprocessed = pd.read_pickle(output_dir / "CH4_train_preprocessed.pkl")
test_preprocessed = pd.read_pickle(output_dir / "CH4_test_preprocessed.pkl")

# %%
train_preprocessed.head()
# Out:
#             CH4_preprocessed  value_unc qcflag
# 1991-01-06          1719.845       2.71    ...
# 1991-01-13          1736.940       2.71    ...
# 1991-01-20          1728.335       2.71    ...
# 1991-01-27          1716.080       2.71    ...
# 1991-02-03          1727.430       2.71    ...

# %%
train_preprocessed.describe()
# Out:
#        CH4_preprocessed    value_unc
# count       1669.000000  1639.000000
# mean        1810.978201     1.539019
# std           51.454037     0.711564
# min         1709.020000     0.575000
# 25%         1773.175000     0.910000
# 50%         1799.530000     1.400000
# 75%         1845.730000     2.050000
# max         1970.875000     2.710000

# %%
print("train_preprocessed min and max date index:")
print(f"min: {train_preprocessed.index.min()}")
print(f"max: {train_preprocessed.index.max()}")
# Out:
# train_preprocessed min and max date index:
# min: 1991-01-06 00:00:00
# max: 2022-12-25 00:00:00

# %%
test_preprocessed.head()
# Out:
#             CH4_preprocessed  value_unc qcflag
# 2023-01-01         1931.1000      0.575    ...
# 2023-01-08         1933.3625      0.575    ...
# 2023-01-15         1929.8025      0.575    ...
# 2023-01-22         1941.1150      0.575    ...
# 2023-01-29         1934.8100      0.575    ...

# %%
test_preprocessed.describe()
# Out:
#        CH4_preprocessed     value_unc
# count        105.000000  8.800000e+01
# mean        1941.117616  5.750000e-01
# std           18.761407  1.116585e-16
# min         1906.600000  5.750000e-01
# 25%         1929.217500  5.750000e-01
# 50%         1940.986667  5.750000e-01
# 75%         1953.217500  5.750000e-01
# max         1989.377500  5.750000e-01

# %%
print("test_preprocessed min and max date index:")
print(f"min: {test_preprocessed.index.min()}")
print(f"max: {test_preprocessed.index.max()}")
# Out:
# test_preprocessed min and max date index:
# min: 2023-01-01 00:00:00
# max: 2024-12-29 00:00:00

# %%
# confirm that the gap between train and test sets is one week

print(f"last train_preprocessed index date: {train_preprocessed.index[-1]}")
print(f"first test_preprocessed index date: {test_preprocessed.index[0]}")

train_test_gap = test_preprocessed.index[0] - train_preprocessed.index[-1]
print(f"gap between train and test sets = {train_test_gap}")
# Out:
# last train_preprocessed index date: 2022-12-25 00:00:00
# first test_preprocessed index date: 2023-01-01 00:00:00
# gap between train and test sets = 7 days 00:00:00

# %%
# extract only the CH4 values column from each dataframe

train_preprocessed = train_preprocessed['CH4_preprocessed']
test_preprocessed = test_preprocessed['CH4_preprocessed']

# %%
print(train_preprocessed.describe)
# Out:
# <bound method NDFrame.describe of 1991-01-06    1719.8450
# 1991-01-13    1736.9400
# 1991-01-20    1728.3350
# 1991-01-27    1716.0800
# 1991-02-03    1727.4300
#                 ...
# 2022-11-27    1958.5475
# 2022-12-04    1956.4500
# 2022-12-11    1954.3525
# 2022-12-18    1952.2550
# 2022-12-25    1950.1575
# Freq: W-SUN, Name: CH4_preprocessed, Length: 1669, dtype: float64>

# %%
print(test_preprocessed.describe)
# Out:
# <bound method NDFrame.describe of 2023-01-01    1931.10000
# 2023-01-08    1933.36250
# 2023-01-15    1929.80250
# 2023-01-22    1941.11500
# 2023-01-29    1934.81000
#                  ...
# 2024-12-01    1959.45000
# 2024-12-08    1941.22625
# 2024-12-15    1923.00250
# 2024-12-22    1952.38000
# 2024-12-29    1977.44500
# Freq: W-SUN, Name: CH4_preprocessed, Length: 105, dtype: float64>

# %% [markdown]
# ## model specs, fitted models, and calibration files

# %%
# print the path to where the notebook is running
print(Path.cwd())
# Out:
# C:\Users\aplor\Documents\GitHub\greenhouse-gas-forecasting\notebooks

# %%
output_dir = Path("../data/forecasting_data")

models_dir = output_dir / "fitted_models"
calibration_dir = output_dir / "calibration"

# %%
print(output_dir.resolve())
print(output_dir.exists())
# Out:
# C:\Users\aplor\Documents\GitHub\greenhouse-gas-forecasting\data\forecasting_data
# True

# %% [markdown]
# **Note about path**
# Both data and notebook folders are in the greenhouse-gas-forecasting folder.

# %%
# load the model specs
with open(output_dir / "model_specs.json") as f:
    model_specs = json.load(f)

print("loaded model specs for UCM and SARIMA models")
print(f"\nUCM model specs: {model_specs['UCM']}")
print(f"\nSARIMA model specs: {model_specs['SARIMA']}")
# Out:
# loaded model specs for UCM and SARIMA models
#
# UCM model specs: {'level': 'random walk with drift', 'freq_seasonal': [{'period': 52.18, 'harmonics': 4}], 'stochastic_freq_seasonal': [True], 'autoregressive': 1}
#
# SARIMA model specs: {'order': [1, 1, 1], 'seasonal_order': [1, 0, 1, 52], 'trend': 'c'}

# %%
# load fitted models
# I will load only SARIMA and UCM models since these are the top models based on skill and test forecast CRPS 
fitted_models = {}

for name in ["SARIMA", "UCM"]:
    file = models_dir / f"{name}_fit.pkl"
    with open(file, "rb") as f:
        fitted_models[name] = pickle.load(f)

print(f"loaded {len(fitted_models)} fitted models:")
print(list(fitted_models.keys()))
# Out:
# loaded 2 fitted models:
# ['SARIMA', 'UCM']

# %%
# load calibration data for the top models 
# I will load the calibration data for only SARIMA and UCM models since these are the top models based on skill and test forecast CRPS 
calibration = {}

for name in ["SARIMA", "UCM"]:
    file = calibration_dir / f"{name}_calibration.pkl"
    with open(file, "rb") as f:
        calibration[name] = pickle.load(f)

print(f"loaded {len(calibration)} calibration files:")
print(list(calibration.keys()))
# Out:
# loaded 2 calibration files:
# ['SARIMA', 'UCM']

# %% [markdown]
# # single-origin forecast against test set

# %% [markdown]
# # forecast against test set - pipeline
#
# 1. Fit the model on full training data
# 2. Run rolling_crps on training data to get the results DataFrame
# 3. Trim results to common_start_idx=492
# 4. Apply variance scaling to trimmed results
# 5. Apply ACI to scaled results, extract final alpha_t
# 6. Forecast on test set using the fitted model
# 7. Apply variance scaling and ACI to test forecasts

# %% [markdown]
# ## single-origin forecast for top models

# %%
# Exog for test set per model
# neither model employs an exogenous variable, but am leaving this here for possile
# future use with a model that does.  
exog_test_map = {
    'UCM'    : None,
    'SARIMA' : None
}

all_test_forecasts = {}

for name in fitted_models:
    cal    = calibration[name]        # from run_calibration_pipeline()
    result = fitted_models[name]
    exog_t = exog_test_map[name]

    all_test_forecasts[name] = fc.single_origin_forecast(
        fitted_result=result,
        test_series=test_preprocessed,
        exog_test=exog_t,
        scale_factors=cal['scale_factors'],
        final_alpha=cal['final_alpha'],
        target_coverage=0.95,
    )
    print(f"{name}: forecast complete")
# Out:
# SARIMA: forecast complete
# UCM: forecast complete

# %%
# Compare all models on the test period
summary_records = []

for name, fc_df in all_test_forecasts.items():
    # Full test period
    summary_records.append({
        'model'        : name,
        'period'       : 'full (2023-2024)',
        'mean_crps'    : fc_df['crps'].mean(),
        'mae'          : fc_df['abs_error'].mean(),
        'coverage_95'  : fc_df['covered_aci'].mean(),
        'n_weeks'      : len(fc_df),
    })
    # Split by year
    for year in [2023, 2024]:
        yr_df = fc_df[fc_df['date'].dt.year == year]
        if len(yr_df) > 0:
            summary_records.append({
                'model'      : name,
                'period'     : str(year),
                'mean_crps'  : yr_df['crps'].mean(),
                'mae'        : yr_df['abs_error'].mean(),
                'coverage_95': yr_df['covered_aci'].mean(),
                'n_weeks'    : len(yr_df),
            })

summary_df = pd.DataFrame(summary_records)
print("Mean CRPS 95% nominal coverage from single-origin forecasts\n")
print(summary_df.pivot(index='model', columns='period',
                        values=['mean_crps', 'coverage_95']).round(3))
# Out:
# Mean CRPS 95% nominal coverage from single-origin forecasts
#
#        mean_crps                          coverage_95
# period      2023    2024 full (2023-2024)        2023   2024 full (2023-2024)
# model
# SARIMA     8.382  10.380            9.372       0.943  0.981            0.962
# UCM        7.873   9.379            8.619       1.000  0.981            0.990

# %%
single_origin_test_forecast_summary = pd.DataFrame(summary_df.pivot(index='model', columns='period',
                        values=['mean_crps', 'coverage_95']).round(3))

single_origin_test_forecast_summary
# Out:
#        mean_crps                          coverage_95
# period      2023    2024 full (2023-2024)        2023   2024 full (2023-2024)
# model
# SARIMA     8.382  10.380            9.372       0.943  0.981            0.962
# UCM        7.873   9.379            8.619       1.000  0.981            0.990

# %%
Mean CRPS and nominal 95% coverage from single-origin forecasts

        mean_crps                          coverage_95                        
period       2023    2024 full (2023-2024)        2023   2024 full (2023-2024)
model                                                                         
ETS         9.133   9.722            9.529       0.943  0.981            0.962
SARIMA      8.511  10.028            9.257       0.943  0.981            0.962
SARIMAX    11.264  22.034           16.501       0.887  0.673            0.783
UCM         8.079   9.036            8.589       0.981  0.981            0.981
UCMX       10.846  22.872           16.709       0.887  0.635            0.764
# Out:
#   Cell In[22], line 1
#     Mean CRPS and nominal 95% coverage from single-origin forecasts
#          ^
# SyntaxError: invalid syntax

# %%
# Compare the actual values feeding both runs
# (rerun this in the forecasting notebook, comparing against a fresh
#  in-memory version if you still have access to the modeling notebook's kernel)

print(test_preprocessed.head(10))
print(test_preprocessed.dtype)

# Check precision — count decimal places actually present
print(test_preprocessed.apply(lambda x: len(str(x).split('.')[-1]) if '.' in str(x) else 0).describe())
# Out:
# 2023-01-01    1931.100000
# 2023-01-08    1933.362500
# 2023-01-15    1929.802500
# 2023-01-22    1941.115000
# 2023-01-29    1934.810000
# 2023-02-05    1932.490000
# 2023-02-12    1950.120000
# 2023-02-19    1945.553333
# 2023-02-26    1940.986667
# 2023-03-05    1936.420000
# Freq: W-SUN, Name: CH4_preprocessed, dtype: float64
# float64
# count    105.000000
# mean       4.180952
# std        3.336226
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max       13.000000
# Name: CH4_preprocessed, dtype: float64

# %% [markdown]
# ## single-origin forecast comparison plots

# %%
fig, ax = plt.subplots(figsize=(14, 5))

train_tail = train_preprocessed.loc['2021':]
ax.plot(train_tail.index, train_tail.values, color='gray', linewidth=1.2,
        alpha=0.6, label='Training data (2021–2022)')
ax.plot(test_preprocessed.index, test_preprocessed.values, color='black',
        linewidth=1.5, label='Observed (2023–2024)')

colors = {'UCM': '#0072B2', 'SARIMA': '#D55E00'}
for name in ['UCM', 'SARIMA']:
    fc = all_test_forecasts[name]
    ax.plot(fc['date'], fc['y_pred'], color=colors[name],
             linewidth=1.3, linestyle='--', label=f'{name} forecast')
    ax.fill_between(fc['date'], fc['lower_aci'], fc['upper_aci'],
                     color=colors[name], alpha=0.15)

# Seasonal naive reference (52-week lag of training)
naive_vals = train_preprocessed.reindex(
    test_preprocessed.index - pd.Timedelta(weeks=52)
).values
ax.plot(test_preprocessed.index, naive_vals, color='gray',
        linewidth=1, linestyle=':', label='Seasonal naive')

ax.axvline(train_preprocessed.index[-1], color='gray', linestyle=':', linewidth=1)
ax.set_title('CH4 Forecast Comparison: 2023–2024', fontsize=13)
ax.set_ylabel('CH4 (ppb)')
ax.legend(fontsize=9, loc='upper left')
ax.grid(True, linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()
